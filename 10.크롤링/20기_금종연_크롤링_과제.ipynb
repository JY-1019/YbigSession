# %% [markdown]
# # request, bs4

# %%
from bs4 import BeautifulSoup

# 첫 번째 인자: 파싱할 객체
# 두 번째 인자: 사용할 parser(구문 분석기)
soup = BeautifulSoup(html, 'html.parser')

# %%
html = '''
<html>
  <head>
    <title>Example HTML</title>
  </head>
  <body>
    <div id='first' class='Example'>
      <h3 title='Good Content Title'>Contents Title</h3>
      <p>Test contents</p>
    </div>
    <div id='second' class='Example'>
      <p>Text1</p>
      <p>Text2</p>
      <p>Text3</p>
    </div>
  </body>
</html>
'''

# %%
tag = soup.find('h3')
print(tag)
tag.get_text()
# Out:
# <h3 title="Good Content Title">Contents Title</h3>
# 'Contents Title'

# %%
soup.find_all({'p', 'h3'})
# Out:
# [<h3 title="Good Content Title">Contents Title</h3>,
#  <p>Test contents</p>,
#  <p>Text1</p>,
#  <p>Text2</p>,
#  <p>Text3</p>]

# %%
soup.find('div', id='second')
# Out:
# <div class="Example" id="second">
# <p>Text1</p>
# <p>Text2</p>
# <p>Text3</p>
# </div>

# %%
attrs = {
    'id': 'second',
    'class': 'Example'
}
soup.find('div', attrs)
# Out:
# <div class="Example" id="second">
# <p>Text1</p>
# <p>Text2</p>
# <p>Text3</p>
# </div>

# %% [markdown]
# # Beautiful soup 예제

# %%
import requests
import re
from bs4 import BeautifulSoup

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}

# %%
for i in range(1, 6):
    #print("페이지 :", i)
    url = "https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page={}&rocketAll=false&searchIndexingToken=1=4&backgroundColor=".format(i)

    res = requests.get(url, headers=headers)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml")

    items = soup.find_all("li", attrs={"class":re.compile("^search-product")})
    
    for item in items:
        # 광고 제품은 제외
        ad_badge = item.find("span", attrs={"class":"ad-badge-text"})
        if ad_badge:
            #print("  <광고 상품 제외합니다>")
            continue

        name = item.find("div", attrs={"class":"name"}).get_text() # 제품명
        # 애플 제품 제외
        if "Apple" in name:
            #print("  <Apple 상품 제외합니다>")
            continue
            
        price = item.find("strong", attrs={"class":"price-value"})
        
        if price:
            price = price.get_text()# 가격
        # 리뷰 100개 이상, 평점 4.5 이상 되는 것만 조회
        rate = item.find("em", attrs={"class":"rating"}) # 평점
        if rate:
            rate = rate.get_text()
        else:
            #print("  <평점 없는 상품 제외합니다>")
            continue

        rate_cnt = item.find("span", attrs={"class":"rating-total-count"}) # 평점 수 
        if rate_cnt:
            rate_cnt = rate_cnt.get_text()[1:-1] # 예 : (26)
        else:
            #print("  <평점 수 없는 상품 제외합니다>")
            continue

        link = item.find("a", attrs={"class":"search-product-link"})["href"]

        if float(rate) >= 4.5 and int(rate_cnt) >= 100:
            #print(name, price, rate, rate_cnt)
            print(f"제품명 : {name}")
            print(f"가격 : {price}")
            print(f"평점 : {rate}점 ({rate_cnt}개)")
            print("바로가기 : {}".format("https://www.coupang.com" + link))
            print("-"*100) # 줄긋기
# Out:
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 셀러론, 128GB, 4GB, WIN10 Home, 14U390-ME1TK
# 가격 : 417,000
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652939&vendorItemId=73553348848
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 갤럭시북 15.6, 미스틱 블루, 코어i5 11세대, 512GB, 16GB, WIN10 Home, NT750XDZ-A51AU
# 가격 : 1,161,150
# 평점 : 5.0점 (614개)
# 바로가기 : https://www.coupang.com/vp/products/5540996827?itemId=8724803682&vendorItemId=76011850910&pickType=COU_PICK
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 노트북 15.6, Abyss Blue, ideaPad Slim3-15ALC R5 82KU, 라이젠5, 256GB, 20GB, Free DOS
# 가격 : 557,800
# 평점 : 5.0점 (179개)
# 바로가기 : https://www.coupang.com/vp/products/6148861528?itemId=11853952978&vendorItemId=79127153424
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 셀러론, 128GB, 8GB, WIN10 Home, 14U390-ME1TK
# 가격 : 478,000
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652936&vendorItemId=73553348831
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 노트북 15.6, Sand, ideaPad Slim3-15ALC R5 82KU, 라이젠5, 256GB, 20GB, Free DOS
# 가격 : 557,800
# 평점 : 5.0점 (179개)
# 바로가기 : https://www.coupang.com/vp/products/6148861528?itemId=11853952989&vendorItemId=79127153475
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 노트북 플러스2 15.6, 퓨어 화이트, 셀러론, NVMe128GB, 8GB, WIN10 Pro, NT550XDA-K14AW
# 가격 : 528,000
# 평점 : 5.0점 (2703개)
# 바로가기 : https://www.coupang.com/vp/products/5358757879?itemId=7416308410&vendorItemId=80022025347
# ----------------------------------------------------------------------------------------------------
# 제품명 : 에이수스 2021 ZenBook Duo14, 셀레스티얼 블루, 코어i7 11세대, 1TB, 16GB, WIN10 Home, UX482EA-HY109T
# 가격 : 1,746,000
# 평점 : 5.0점 (201개)
# 바로가기 : https://www.coupang.com/vp/products/5607585100?itemId=6599508933&vendorItemId=73893442265
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 셀러론, 256GB, 8GB, WIN10 Home, 14U390-ME1TK
# 가격 : 507,000
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652929&vendorItemId=73553348801
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 노트북 플러스2 15.6, 퓨어 화이트, 셀러론, NVMe128GB + SSD256GB, 8GB, WIN10 Pro, NT550XDA-K14AW
# 가격 : 597,000
# 평점 : 5.0점 (2703개)
# 바로가기 : https://www.coupang.com/vp/products/5358757879?itemId=7416308413&vendorItemId=80081596720
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 셀러론, 64GB, 4GB, WIN10 Home, 14U390-ME1TK
# 가격 : 510,000
# 평점 : 4.5점 (105개)
# 바로가기 : https://www.coupang.com/vp/products/1900541401?itemId=3228221697&vendorItemId=80284019826
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 S 13.3, 얼씨 골드, 코어i5, 512GB, 8GB, WIN10 Home, NT767XCL-KLTE
# 가격 : 899,000
# 평점 : 5.0점 (773개)
# 바로가기 : https://www.coupang.com/vp/products/2316242692?itemId=3055968087&vendorItemId=79823869697
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 셀러론, 64GB, 4GB, WIN10 Home, 14U390-ME1TK
# 가격 : 510,000
# 평점 : 4.5점 (105개)
# 바로가기 : https://www.coupang.com/vp/products/1900541401?itemId=3228221697&vendorItemId=80284019826
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 S 13.3, 얼씨 골드, 코어i5, 512GB, 8GB, WIN10 Home, NT767XCL-KLTE
# 가격 : 899,000
# 평점 : 5.0점 (773개)
# 바로가기 : https://www.coupang.com/vp/products/2316242692?itemId=3055968087&vendorItemId=79823869697
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 15.6, 화이트, 펜티엄, 256GB, 4GB, Free DOS, 15UD50N-LX20K
# 가격 : 820,000
# 평점 : 5.0점 (220개)
# 바로가기 : https://www.coupang.com/vp/products/1605328033?itemId=3176445188&vendorItemId=80009925757
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 셀러론, 256GB, 8GB, WIN10 Home, 14U390-ME1TK
# 가격 : 507,000
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652929&vendorItemId=73553348801
# ----------------------------------------------------------------------------------------------------
# 제품명 : HP 2021 노트북 15s, 내츄럴 실버, 라이젠7 3세대, 512GB, 8GB, WIN10 Home, 15s-eq1158AU
# 가격 : 1,225,000
# 평점 : 5.0점 (224개)
# 바로가기 : https://www.coupang.com/vp/products/5237101765?itemId=7389456793&vendorItemId=80022306060
# ----------------------------------------------------------------------------------------------------
# 제품명 : 에이수스 2021 ZenBook Duo14, 셀레스티얼 블루, 코어i7 11세대, 1TB, 16GB, WIN10 Home, UX482EA-HY109T
# 가격 : 1,746,000
# 평점 : 5.0점 (201개)
# 바로가기 : https://www.coupang.com/vp/products/5607585100?itemId=6599508933&vendorItemId=73893442265
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 S 13.3, 얼씨 골드, 코어i3, 256GB, 8GB, WIN10 Home, NT767XCM-K38
# 가격 : 1,468,000
# 평점 : 5.0점 (773개)
# 바로가기 : https://www.coupang.com/vp/products/2316242692?itemId=3667662413&vendorItemId=80486331431
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 IdeaPad Slim3 15.6, SAND, 코어i3 11세대, 256GB, 4GB, WIN10 S, 82H800GCKR
# 가격 : 559,000
# 평점 : 5.0점 (156개)
# 바로가기 : https://www.coupang.com/vp/products/5607437899?itemId=10300573902&vendorItemId=77582884202
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 셀러론, 256GB, 4GB, WIN10 Home, 14U390-ME1TK
# 가격 : 444,000
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652935&vendorItemId=73553348815
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 ThinkPad E15, 블랙, 라이젠5 4세대, 256GB, 8GB, Free DOS, 20YG0010KD
# 가격 : 645,190
# 평점 : 5.0점 (353개)
# 바로가기 : https://www.coupang.com/vp/products/5762131379?itemId=9761259024&vendorItemId=77044957874
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 S 13.3, 머큐리 그레이, 코어i5, 512GB, 8GB, WIN10 Home, NT767XCL-KLTES
# 가격 : 899,000
# 평점 : 5.0점 (773개)
# 바로가기 : https://www.coupang.com/vp/products/2316242692?itemId=3055967871&vendorItemId=80279614832
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG 울트라PC 15U560 6세대 i5 지포스940M 15.6인치 윈도우10, SSD 128GB + HDD 500GB, 8GB, 포함
# 가격 : 469,000
# 평점 : 4.5점 (171개)
# 바로가기 : https://www.coupang.com/vp/products/6241227771?itemId=12599056071&vendorItemId=76740961824
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 갤럭시북 15.6, 미스틱 블루, 코어i7 11세대, 512GB, 16GB, WIN10 Home, NT750XDZ-A71AU
# 가격 : 1,449,000
# 평점 : 5.0점 (614개)
# 바로가기 : https://www.coupang.com/vp/products/5540996827?itemId=8884768419&vendorItemId=79770849674
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 15.6, 화이트, 라이젠3 3세대, 256GB, 8GB, WIN10 Home, 15U40N-GR36K
# 가격 : 769,000
# 평점 : 5.0점 (1259개)
# 바로가기 : https://www.coupang.com/vp/products/4919104915?itemId=3402491499&vendorItemId=80106380735
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 ThinkPad E15, 블랙, 라이젠3 4세대, 256GB, 8GB, Free DOS, 20YG000YKD
# 가격 : 1,198,090
# 평점 : 5.0점 (353개)
# 바로가기 : https://www.coupang.com/vp/products/5762131379?itemId=9761258863&vendorItemId=80208299530
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 프로360 NT950QDY-A51AS (i5-1135G7 39.6cm WIN10 미스틱실버), 미스틱 실버, 코어i5 11세대, 512GB, 16GB, WIN10 Home
# 가격 : 2,990,000
# 평점 : 5.0점 (250개)
# 바로가기 : https://www.coupang.com/vp/products/5410796394?itemId=8171114579&vendorItemId=80141634376
# ----------------------------------------------------------------------------------------------------
# 제품명 : 한성컴퓨터 2021 TFG 17.3, 블랙, 라이젠7 3세대, 500GB, 16GB, Free DOS, TFG7476HS
# 가격 : 1,459,000
# 평점 : 5.0점 (138개)
# 바로가기 : https://www.coupang.com/vp/products/5196944537?itemId=7232945470&vendorItemId=74524493094
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG 울트라PC 15U560 6세대 i5 지포스940M 15.6인치 윈도우10, SSD 128GB + HDD 500GB, 8GB, 포함
# 가격 : 469,000
# 평점 : 4.5점 (171개)
# 바로가기 : https://www.coupang.com/vp/products/6241227771?itemId=12599056071&vendorItemId=76740961824
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 이온 15.6, 아우라 실버, 코어i5 10세대, 256GB, 8GB, WIN10 Home, NT950XCR-G58A
# 가격 : 1,639,000
# 평점 : 5.0점 (224개)
# 바로가기 : https://www.coupang.com/vp/products/4672371918?itemId=2098033655&vendorItemId=70096918925
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 갤럭시북 15.6, 미스틱 블루, 코어i5 11세대, 512GB, 16GB, WIN10 Home, NT750XDZ-A51AU
# 가격 : 1,161,150
# 평점 : 5.0점 (614개)
# 바로가기 : https://www.coupang.com/vp/products/5540996827?itemId=8724803682&vendorItemId=76011850910
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2020 Gaming 3i 15IMH LEGEND PRO, 오닉스 블랙, 코어i5 10세대, 512GB, 16GB, WIN10 Home, 81Y400DGKR
# 가격 : 1,149,000
# 평점 : 4.5점 (186개)
# 바로가기 : https://www.coupang.com/vp/products/1713335697?itemId=6062714749&vendorItemId=80116893700
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 ThinkPad E15, 블랙, 라이젠7 4세대, 512GB, 16GB, WIN10 Pro, 20YG0015KR
# 가격 : 1,680,000
# 평점 : 5.0점 (353개)
# 바로가기 : https://www.coupang.com/vp/products/5762131379?itemId=9761259195&vendorItemId=79870803964
# ----------------------------------------------------------------------------------------------------
# 제품명 : 에이수스 2020 Vivobook 15.6, 드리미 화이트, 코어i5 11세대, 256GB, 8GB, Free DOS, X513EA-BQ031
# 가격 : 928,000
# 평점 : 5.0점 (225개)
# 바로가기 : https://www.coupang.com/vp/products/4997466770?itemId=9604271139&vendorItemId=80268053412
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 IdeaPad Slim3 15.6, SAND, 코어i3 11세대, 256GB, 4GB, WIN10 S, 82H800GCKR
# 가격 : 559,000
# 평점 : 5.0점 (156개)
# 바로가기 : https://www.coupang.com/vp/products/5607437899?itemId=10300573902&vendorItemId=77582884202
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 노트북 플러스2 15.6, 미스틱 그레이, 펜티엄, NVMe256GB, 8GB, WIN10 Pro, NT550XDA-K24AG
# 가격 : 649,000
# 평점 : 5.0점 (2703개)
# 바로가기 : https://www.coupang.com/vp/products/5358757879?itemId=7901781643&vendorItemId=75191177470
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 펜티엄, 256GB, 8GB, WIN10 Home, 14U390-ME2TK
# 가격 : 585,520
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652757&vendorItemId=73553348707
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 펜티엄, 128GB, 8GB, WIN10 S, 14U390-ME2TK
# 가격 : 547,000
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652753&vendorItemId=73553348696
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 15.6, 화이트, 라이젠7 3세대, 256GB, 16GB, Free DOS, 15UD40N-GX76K
# 가격 : 929,630
# 평점 : 5.0점 (1259개)
# 바로가기 : https://www.coupang.com/vp/products/4919104915?itemId=9818962411&vendorItemId=77102492022
# ----------------------------------------------------------------------------------------------------
# 제품명 : 에이수스 2020 Vivobook 15.6, 드리미 화이트, 코어i5 11세대, 256GB, 8GB, Free DOS, X513EA-BQ031
# 가격 : 928,000
# 평점 : 5.0점 (225개)
# 바로가기 : https://www.coupang.com/vp/products/4997466770?itemId=9604271139&vendorItemId=80268053412
# ----------------------------------------------------------------------------------------------------
# 제품명 : 에이수스 2021 Vivobook 15, 드리미화이트, 코어i5 11세대, 512GB, 8GB, Free DOS, X513EA-CP001
# 가격 : 676,400
# 평점 : 4.5점 (108개)
# 바로가기 : https://www.coupang.com/vp/products/4962777708?itemId=8190278758&vendorItemId=73870043494
# ----------------------------------------------------------------------------------------------------
# 제품명 : 델 2021 G15, 펜텀 그레이 위드 스펙클, 라이젠7 4세대, 512GB, 16GB, WIN10 Home, DG5515-WH01DKR
# 가격 : 1,699,000
# 평점 : 5.0점 (108개)
# 바로가기 : https://www.coupang.com/vp/products/5671438112?itemId=9104260632&vendorItemId=76390529350
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2021 그램 16, 스노우 화이트, 코어i7 11세대, 256GB, 8GB, Free DOS, 16ZD90P-GX70K
# 가격 : 2,250,000
# 평점 : 5.0점 (1045개)
# 바로가기 : https://www.coupang.com/vp/products/4618899172?itemId=5721540620&vendorItemId=80247744301
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 13, 화이트, 라이젠7 3세대, 256GB, 16GB, WIN10 Home, 13U70P-GA76K
# 가격 : 1,199,000
# 평점 : 5.0점 (603개)
# 바로가기 : https://www.coupang.com/vp/products/4889782695?itemId=6372254297&vendorItemId=73667428240
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 15.6, 화이트, 라이젠3 3세대, 256GB, 8GB, WIN10 Home, 15U40N-GR36K
# 가격 : 769,000
# 평점 : 5.0점 (1259개)
# 바로가기 : https://www.coupang.com/vp/products/4919104915?itemId=3402491499&vendorItemId=80106380735
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 갤럭시북 프로 15.6, 미스틱 실버, 코어i5 11세대, 256GB, 16GB, WIN10 Home, NT950XDY-A51AS
# 가격 : 1,479,000
# 평점 : 5.0점 (457개)
# 바로가기 : https://www.coupang.com/vp/products/5414943153?itemId=8139453673&vendorItemId=79823869499
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2020 V14, 그레이, 라이젠5 3세대, 256GB, 8GB, Free DOS, 82DQ003AKR
# 가격 : 1,399,000
# 평점 : 4.5점 (408개)
# 바로가기 : https://www.coupang.com/vp/products/1676672325?itemId=2856499922&vendorItemId=80208275047
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 노트북 플러스2 15.6, 블레이드 블랙, 코어i7 11세대, 256GB, 16GB, WIN10 Home, NT560XDZ-G78AB
# 가격 : 2,649,000
# 평점 : 5.0점 (174개)
# 바로가기 : https://www.coupang.com/vp/products/6090025917?itemId=11360085348&vendorItemId=80141501687
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 S 13.3, 머큐리 그레이, 코어i5, 256GB, 8GB, WIN10 Home, NT767XCL-KC58S
# 가격 : 851,180
# 평점 : 5.0점 (773개)
# 바로가기 : https://www.coupang.com/vp/products/2316242692?itemId=10540738117&vendorItemId=77822241145
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 갤럭시북 프로 15.6, 미스틱 실버, 코어i5 11세대, 256GB, 16GB, WIN10 Home, NT950XDX-G51AS
# 가격 : 2,546,160
# 평점 : 5.0점 (344개)
# 바로가기 : https://www.coupang.com/vp/products/5417572839?itemId=8139453985&vendorItemId=80124187433
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 ThinkPad E15, 블랙, 라이젠7 4세대, 512GB, 16GB, WIN10 Pro, 20YG0015KR
# 가격 : 1,680,000
# 평점 : 5.0점 (353개)
# 바로가기 : https://www.coupang.com/vp/products/5762131379?itemId=9761259195&vendorItemId=79870803964
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 IdeaPad Slim3 17.3, 혼합색상, 라이젠7 5세대, 256GB, 8GB, Free DOS, 82KV0023KR
# 가격 : 881,020
# 평점 : 5.0점 (104개)
# 바로가기 : https://www.coupang.com/vp/products/5503631695?itemId=8557241950&vendorItemId=76179971896
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG 울트라PC 15U560 6세대 i5 지포스940M 15.6인치 윈도우10, SSD256GB + HDD 500GB, 8GB, 포함
# 가격 : 499,000
# 평점 : 4.5점 (171개)
# 바로가기 : https://www.coupang.com/vp/products/6241227771?itemId=12570278608&vendorItemId=77744791107
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 15.6, 화이트, 라이젠5 3세대, 256GB, 8GB, WIN10 Home, 15U40N-GR56K
# 가격 : 884,900
# 평점 : 5.0점 (1259개)
# 바로가기 : https://www.coupang.com/vp/products/4919104915?itemId=3405196420&vendorItemId=71391804182
# ----------------------------------------------------------------------------------------------------
# 제품명 : HP 2021 노트북 15s, 스노우 화이트, 라이젠5 3세대, 256GB, 4GB, Free DOS, 15s-EQ1151AU
# 가격 : 529,000
# 평점 : 5.0점 (224개)
# 바로가기 : https://www.coupang.com/vp/products/5237101765?itemId=7417242104&vendorItemId=74708203099
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 이온 15.6, 아우라 실버, 코어i5 10세대, 256GB, 16GB, Linux, NT950XCR-G58A
# 가격 : 1,339,000
# 평점 : 5.0점 (224개)
# 바로가기 : https://www.coupang.com/vp/products/4672371918?itemId=3438553996&vendorItemId=71425040479
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 ThinkPad E15, 블랙, 라이젠7 4세대, 512GB, 16GB, WIN10 Pro, 20YJ0005KR
# 가격 : 1,126,010
# 평점 : 5.0점 (353개)
# 바로가기 : https://www.coupang.com/vp/products/5762131379?itemId=10489763440&vendorItemId=77771457662
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 펜티엄, 256GB, 4GB, WIN10 Home, 14U390-ME2TK
# 가격 : 829,500
# 평점 : 4.5점 (373개)
# 바로가기 : https://www.coupang.com/vp/products/4841548763?itemId=6257652751&vendorItemId=80104447562
# ----------------------------------------------------------------------------------------------------
# 제품명 : 레노버 2021 노트북 15.6, Abyss Blue, ideaPad Slim3-15ALC R5 82KU, 라이젠5, 1280GB, 8GB, Free DOS
# 가격 : 723,000
# 평점 : 5.0점 (179개)
# 바로가기 : https://www.coupang.com/vp/products/6148861528?itemId=11853952940&vendorItemId=79127153247
# ----------------------------------------------------------------------------------------------------
# 제품명 : 기가바이트 2021 Gaming G5 15.6, 코어i5 10세대, 512GB, 16GB, Free DOS, G5 KC i5
# 가격 : 1,499,000
# 평점 : 5.0점 (296개)
# 바로가기 : https://www.coupang.com/vp/products/5125785609?itemId=6809341840&vendorItemId=74101991899
# ----------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2021 노트북 플러스2 15.6, 미스틱 그레이, 셀러론, NVMe128GB, 8GB, WIN10 Pro, NT550XDA-K14AG
# 가격 : 528,000
# 평점 : 5.0점 (2703개)
# 바로가기 : https://www.coupang.com/vp/products/5358757879?itemId=7416308307&vendorItemId=80022414201
# ----------------------------------------------------------------------------------------------------
# 제품명 : LG전자 2020 울트라 PC 14, 화이트, 펜티엄, 64GB, 4GB, WIN10 Home, 14U390-ME2TK
# 가격 : 458,000
# 평점 : 4.5점 (105개)
# 바로가기 : https://www.coupang.com/vp/products/1900541401?itemId=3259240186&vendorItemId=71246299850
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Selenium 예제

# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome()
url = "https://flight.naver.com/"
browser.get(url) # url 로 이동
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[4]/div/div/div[2]/div[2]/button[1]').click()

# %%
browser.find_element_by_xpath('//*[@id="__next"]/div/div[1]/div[9]/div[2]/div[1]/div[2]/div/div[2]/table/tbody/tr[3]/td[5]/button').click() # [0] -> 이번달
# browser.find

# %% [markdown]
# # Selenium 예제 (과제)

# %%
cine21_url = 'http://www.cine21.com/rank/person/'
path = '/Applications/chromedriver'
options = webdriver.ChromeOptions()
options.add_argument('headless')
driver = webdriver.Chrome(path, options = options)

actors_info_list = list()
driver.get(cine21_url)

cine21_url = 'http://www.cine21.com/rank/person/'
path = '/Applications/chromedriver'
options = webdriver.ChromeOptions()
options.add_argument('headless')
driver = webdriver.Chrome(path, options = options)

actors_info_list = list()
driver.get(cine21_url)

for i in range(1, 11):
    page = driver.find_element_by_xpath('//*[@id="rank_holder"]/div/div/a[{}]'.format(i))
    page.click()
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    actors = soup.select('li.people_li div.name')
    p = soup.select('li.people_li ul.num_info')
    r = soup.select('li.people_li span.grade')

    performance = list()
    rank = list()
    
    for i in p:
        performance.append(i.find('strong').text)
    for i in r:
        rank.append(i.text)

          
    for index, actor in enumerate(actors):
        actor_info_dict = dict()
        actor_name = re.sub('\(\w*\)', '', actor.text)
        actor_info_dict['이름'] = actor_name
        actor_info_dict['흥행지수'] = performance[index]
        actor_info_dict['랭킹'] = rank[index]

        actor_link = 'http://www.cine21.com' + actor.select_one('a')['href']
        response_actor = requests.get(actor_link)
        soup_actor = BeautifulSoup(response_actor.text, 'html.parser')
        default_info = soup_actor.select_one('ul.default_info')
        actor_details = default_info.select('li')
    
        for actor_detail in actor_details:
            actor_detail_key = actor_detail.select_one('span.tit').text
            actor_detail_value = re.sub('<span.*>.*</span>', '', str(actor_detail))
            actor_detail_value = re.sub('<.*?>', '', actor_detail_value)
            actor_info_dict[actor_detail_key] = actor_detail_value
        
        actors_info_list.append(actor_info_dict)

# %%
actors_info_list
# Out:
# [{'이름': '강하늘',
#   '흥행지수': '79,188',
#   '랭킹': '1',
#   '다른 이름': '김하늘',
#   '직업': '배우',
#   '생년월일': '1990-02-21',
#   '성별': '남',
#   '홈페이지': '\nhttp://weibo.com/galpos3?is_hot=1\n',
#   '신장/체중': '181cm, 70kg',
#   '학교': '중앙대학교 연극학과'},
#  {'이름': '한효주',
#   '흥행지수': '67,411',
#   '랭킹': '2',
#   '직업': '배우',
#   '생년월일': '1987-02-22',
#   '성별': '여',
#   '홈페이지': '\nhttps://www.facebook.com/hhj.official\n',
#   '신장/체중': '170cm',
#   '학교': '동국대학교 연극영화',
#   '취미': '영화감상'},
#  {'이름': '이광수',
#   '흥행지수': '59,525',
#   '랭킹': '3',
#   '직업': '배우',
#   '생년월일': '1985-07-14',
#   '성별': '남',
#   '홈페이지': '\nhttps://twitter.com/masijacoke85\nhttps://www.instagram.com/masijacoke850714/\n',
#   '신장/체중': '190cm',
#   '소속사': '킹콩엔터테인먼트'},
#  {'이름': '권상우',
#   '흥행지수': '48,151',
#   '랭킹': '4',
#   '다른 이름': 'Kwon Sang Woo',
#   '직업': '배우',
#   '생년월일': '1976-08-05',
#   '성별': '남',
#   '신장/체중': '183cm, 72kg',
#   '학교': '한남대학교 미술교육학 학사',
#   '취미': '수영, 헬스, 복싱',
#   '특기': '농구',
#   '소속사': '벨액터스 엔터테인먼트'},
#  {'이름': '조진웅',
#   '흥행지수': '45,664',
#   '랭킹': '5',
#   '다른 이름': '조원준',
#   '직업': '배우',
#   '생년월일': '1976-03-03',
#   '성별': '남',
#   '홈페이지': '\nhttp://www.facebook.com/saram.chojinwoong\n',
#   '신장/체중': '185cm, 98kg',
#   '학교': '경성대학교 연극영화',
#   '특기': '진도 북춤',
#   '소속사': '㈜사람엔터테인먼트'},
#  {'이름': '박희순',
#   '흥행지수': '40,500',
#   '랭킹': '6',
#   '직업': '배우',
#   '생년월일': '1970-02-13',
#   '성별': '남',
#   '홈페이지': '\nhttps://twitter.com/sulebari\n',
#   '신장/체중': '180cm, 70kg',
#   '학교': '서울예술대학 연극과'},
#  {'이름': '채수빈',
#   '흥행지수': '38,521',
#   '랭킹': '7',
#   '직업': '배우',
#   '생년월일': '1994-07-10',
#   '성별': '여',
#   '홈페이지': '\nhttps://instagram.com/soobinms/\nhttps://www.facebook.com/OfficialChaesoobin\n'},
#  {'이름': '강하늘',
#   '흥행지수': '79,188',
#   '랭킹': '1',
#   '다른 이름': '김하늘',
#   '직업': '배우',
#   '생년월일': '1990-02-21',
#   '성별': '남',
#   '홈페이지': '\nhttp://weibo.com/galpos3?is_hot=1\n',
#   '신장/체중': '181cm, 70kg',
#   '학교': '중앙대학교 연극학과'},
#  {'이름': '한효주',
#   '흥행지수': '67,411',
#   '랭킹': '2',
#   '직업': '배우',
#   '생년월일': '1987-02-22',
#   '성별': '여',
#   '홈페이지': '\nhttps://www.facebook.com/hhj.official\n',
#   '신장/체중': '170cm',
#   '학교': '동국대학교 연극영화',
#   '취미': '영화감상'},
#  {'이름': '이광수',
#   '흥행지수': '59,525',
#   '랭킹': '3',
#   '직업': '배우',
#   '생년월일': '1985-07-14',
#   '성별': '남',
#   '홈페이지': '\nhttps://twitter.com/masijacoke85\nhttps://www.instagram.com/masijacoke850714/\n',
#   '신장/체중': '190cm',
#   '소속사': '킹콩엔터테인먼트'},
#  {'이름': '권상우',
#   '흥행지수': '48,151',
#   '랭킹': '4',
#   '다른 이름': 'Kwon Sang Woo',
#   '직업': '배우',
#   '생년월일': '1976-08-05',
#   '성별': '남',
#   '신장/체중': '183cm, 72kg',
#   '학교': '한남대학교 미술교육학 학사',
#   '취미': '수영, 헬스, 복싱',
#   '특기': '농구',
#   '소속사': '벨액터스 엔터테인먼트'},
#  {'이름': '조진웅',
#   '흥행지수': '45,664',
#   '랭킹': '5',
#   '다른 이름': '조원준',
#   '직업': '배우',
#   '생년월일': '1976-03-03',
#   '성별': '남',
#   '홈페이지': '\nhttp://www.facebook.com/saram.chojinwoong\n',
#   '신장/체중': '185cm, 98kg',
#   '학교': '경성대학교 연극영화',
#   '특기': '진도 북춤',
#   '소속사': '㈜사람엔터테인먼트'},
#  {'이름': '박희순',
#   '흥행지수': '40,500',
#   '랭킹': '6',
#   '직업': '배우',
#   '생년월일': '1970-02-13',
#   '성별': '남',
#   '홈페이지': '\nhttps://twitter.com/sulebari\n',
#   '신장/체중': '180cm, 70kg',
#   '학교': '서울예술대학 연극과'},
#  {'이름': '채수빈',
#   '흥행지수': '38,521',
#   '랭킹': '7',
#   '직업': '배우',
#   '생년월일': '1994-07-10',
#   '성별': '여',
#   '홈페이지': '\nhttps://instagram.com/soobinms/\nhttps://www.facebook.com/OfficialChaesoobin\n'},
#  {'이름': '권율',
#   '흥행지수': '35,438',
#   '랭킹': '8',
#   '다른 이름': '권세인;Kwon Sein',
#   '직업': '배우',
#   '생년월일': '1982-06-29',
#   '성별': '남',
#   '홈페이지': '\nhttps://www.facebook.com/saram.kwonyul\n',
#   '학교': '중앙대학교 연극학과'},
#  {'이름': '박소담',
#   '흥행지수': '32,639',
#   '랭킹': '9',
#   '직업': '배우',
#   '생년월일': '1991-09-08',
#   '성별': '여',
#   '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/park-so-dam/\n',
#   '소속사': '아티스트컴퍼니'},
#  {'이름': '김성오',
#   '흥행지수': '31,912',
#   '랭킹': '10',
#   '직업': '배우',
#   '생년월일': '1978-09-15',
#   '성별': '남',
#   '신장/체중': '180cm, 70kg',
#   '취미': '낚시, 당구',
#   '특기': '스노우보드'},
#  {'이름': '박명훈',
#   '흥행지수': '30,378',
#   '랭킹': '11',
#   '직업': '배우',
#   '생년월일': '1975-05-28',
#   '성별': '남'},
#  {'이름': '설경구',
#   '흥행지수': '30,350',
#   '랭킹': '12',
#   '다른 이름': '薛景求',
#   '직업': '배우',
#   '생년월일': '1968-05-01',
#   '성별': '남',
#   '홈페이지': '\nhttps://www.facebook.com/cjesgyeonggu\n',
#   '신장/체중': '175cm, 64kg',
#   '학교': '한양대학교 연극영화과 학사'},
#  {'이름': '오세훈',
#   '흥행지수': '28,891',
#   '랭킹': '13',
#   '원어명': '세훈',
#   '다른 이름': '엑소;EXO',
#   '직업': '가수',
#   '생년월일': '1994-04-12',
#   '성별': '남',
#   '홈페이지': '\nhttps://instagram.com/oohsehun/\n'},
#  {'이름': '송새벽',
#   '흥행지수': '28,559',
#   '랭킹': '14',
#   '직업': '배우',
#   '생년월일': '1979-12-26',
#   '성별': '남',
#   '홈페이지': '\nhttps://www.facebook.com/cjessaebyeok\n',
#   '신장/체중': '179cm, 70kg',
#   '학교': '군산대학교 철학과'},
#  {'이름': '이선균',
#   '흥행지수': '27,800',
#   '랭킹': '15',
#   '직업': '배우',
#   '생년월일': '1975-03-02',
#   '성별': '남',
#   '신장/체중': '180cm, 70kg',
#   '학교': '한국예술종합학교 연극',
#   '취미': '만화책보기',
#   '소속사': '호두엔터테인먼트'},
#  {'이름': '이얼',
#   '흥행지수': '25,313',
#   '랭킹': '16',
#   '직업': '배우',
#   '생년월일': '1964-00-00',
#   '성별': '남'},
#  {'이름': '유재명',
#   '흥행지수': '25,272',
#   '랭킹': '17',
#   '직업': '배우',
#   '생년월일': '1973-06-03',
#   '성별': '남'},
#  {'이름': '김의성',
#   '흥행지수': '24,479',
#   '랭킹': '18',
#   '직업': '배우',
#   '성별': '남',
#   '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/kim-eui-sung/\n',
#   '소속사': '아티스트컴퍼니'},
#  {'이름': '조우진',
#   '흥행지수': '22,745',
#   '랭킹': '19',
#   '다른 이름': '조신제',
#   '직업': '배우',
#   '생년월일': '1979-01-16',
#   '성별': '남'},
#  {'이름': '정현준',
#   '흥행지수': '20,399',
#   '랭킹': '20',
#   '직업': '배우',
#   '생년월일': '2011-11-08',
#   '성별': '남'},
#  {'이름': '이현욱',
#   '흥행지수': '20,250',
#   '랭킹': '21',
#   '직업': '배우',
#   '생년월일': '1985-06-17',
#   '성별': '남',
#   '신장/체중': '180cm, 68kg'},
#  {'이름': '박인환',
#   '흥행지수': '20,218',
#   '랭킹': '22',
#   '직업': '배우',
#   '생년월일': '1945-01-06',
#   '성별': '남',
#   '학교': '중앙대학교 연극영화과 학사'},
#  {'이름': '배종옥',
#   '흥행지수': '17,691',
#   '랭킹': '23',
#   '직업': '배우',
#   '생년월일': '1964-05-13',
#   '성별': '여',
#   '신장/체중': '163cm, 45kg',
#   '학교': '중앙대 연극영화 -  중앙대신문방송대학원',
#   '특기': '수상 스키'},
#  {'이름': '연우진',
#   '흥행지수': '16,319',
#   '랭킹': '24',
#   '다른 이름': '서지후; 김봉회',
#   '직업': '배우',
#   '생년월일': '1984-07-05',
#   '성별': '남'},
#  {'이름': '백현진',
#   '흥행지수': '15,188',
#   '랭킹': '25',
#   '다른 이름': '어어부 밴드; 어어부 프로젝트; Uhuhboo Project',
#   '직업': '배우',
#   '생년월일': '1972-06-29',
#   '성별': '남',
#   '학교': '홍익대학교 조소학과'},
#  {'이름': '이해영',
#   '흥행지수': '15,164',
#   '랭킹': '26',
#   '직업': '배우',
#   '생년월일': '1970-09-07',
#   '성별': '남',
#   '홈페이지': '\nhttp://instagram.com/lee_hae_young_\n',
#   '학교': '서울예술대학'},
#  {'이름': '오륭',
#   '흥행지수': '12,240',
#   '랭킹': '27',
#   '직업': '배우',
#   '생년월일': '1980-07-31',
#   '성별': '남',
#   '홈페이지': '\nhttp://instagram.com/ryoong56/\n'},
#  {'이름': '박정범',
#   '흥행지수': '10,125',
#   '랭킹': '28',
#   '다른 이름': 'Park Jung Bum',
#   '직업': '감독',
#   '생년월일': '1976-00-00',
#   '성별': '남'},
#  {'이름': '서은수',
#   '흥행지수': '10,109',
#   '랭킹': '29',
#   '직업': '배우',
#   '생년월일': '1994-03-02',
#   '성별': '여',
#   '홈페이지': '\nhttp://instagram.com/jj_minii\n'},
#  {'이름': '박지환',
#   '흥행지수': '9,994',
#   '랭킹': '30',
#   '직업': '배우',
#   '생년월일': '1980-09-05',
#   '성별': '남'},
#  {'이름': '염혜란',
#   '흥행지수': '8,439',
#   '랭킹': '31',
#   '직업': '배우',
#   '생년월일': '1976-00-00',
#   '성별': '여'},
#  {'이름': '김종수',
#   '흥행지수': '7,581',
#   '랭킹': '32',
#   '직업': '배우',
#   '생년월일': '1964-11-30',
#   '성별': '남',
#   '홈페이지': '\nhttp://www.artistcompany.co.kr/portfolio-item/kim-jong-soo/\n',
#   '소속사': '아티스트컴퍼니'},
#  {'이름': '여민정',
#   '흥행지수': '7,025',
#   '랭킹': '33',
#   '직업': '성우',
#   '생년월일': '1975-05-13',
#   '성별': '여'},
#  {'이름': '전배수',
#   '흥행지수': '5,055',
#   '랭킹': '34',
#   '직업': '배우',
#   '생년월일': '1970-06-02',
#   '성별': '남'},
#  {'이름': '허동원',
#   '흥행지수': '4,080',
#   '랭킹': '35',
#   '직업': '배우',
#   '생년월일': '1980-06-09',
#   '성별': '남'},
#  {'이름': '김영은', '흥행지수': '4,057', '랭킹': '36', '직업': '성우', '성별': '여'},
#  {'이름': '안소명', '흥행지수': '3,256', '랭킹': '37', '직업': '성우', '성별': '여'},
#  {'이름': '정혜옥',
#   '흥행지수': '3,043',
#   '랭킹': '38',
#   '직업': '성우',
#   '생년월일': '1981-12-16',
#   '성별': '여'},
#  {'이름': '박유림', '흥행지수': '2,760', '랭킹': '39', '직업': '배우', '성별': '여'},
#  {'이름': '신용우', '흥행지수': '2,606', '랭킹': '40', '직업': '성우', '성별': '남'},
#  {'이름': '윤경호',
#   '흥행지수': '2,530',
#   '랭킹': '41',
#   '직업': '배우',
#   '생년월일': '1980-07-05',
#   '성별': '남'},
#  {'이름': '한지민',
#   '흥행지수': '2,280',
#   '랭킹': '42',
#   '직업': '배우',
#   '생년월일': '1982-11-05',
#   '성별': '여',
#   '홈페이지': '\nhttps://www.instagram.com/roma.emo/\n',
#   '신장/체중': '160cm, 43kg',
#   '학교': '서울여자대학교 사회사업학 학사',
#   '소속사': '아바 엔터테인먼트'},
#  {'이름': '이동욱',
#   '흥행지수': '2,213',
#   '랭킹': '43',
#   '직업': '배우',
#   '생년월일': '1981-11-06',
#   '성별': '남',
#   '홈페이지': '\nhttps://www.facebook.com/OfficialLeeDongWook\nhttps://www.instagram.com/leedongwook_official/\n',
#   '신장/체중': '184cm, 78kg',
#   '학교': '중부대학교 언론방송예술학과',
#   '취미': '운동',
#   '특기': '농구, 스노우보드'},
#  {'이름': '임윤아',
#   '흥행지수': '2,079',
#   '랭킹': '44',
#   '다른 이름': '소녀시대; girlsgeneration; girls generation',
#   '직업': '가수',
#   '생년월일': '1990-05-30',
#   '성별': '여',
#   '홈페이지': '\nhttps://www.instagram.com/yoona__lim/\n',
#   '소속사': 'SM엔터테인먼트'},
#  {'이름': '정유미',
#   '흥행지수': '2,028',
#   '랭킹': '45',
#   '직업': '성우',
#   '생년월일': '1978-07-27',
#   '성별': '여'},
#  {'이름': '이혜영',
#   '흥행지수': '2,012',
#   '랭킹': '46',
#   '직업': '배우',
#   '생년월일': '1971-12-22',
#   '성별': '여',
#   '신장/체중': '168cm, 48kg',
#   '취미': '영화감상',
#   '소속사': 'HB엔터테인먼트'},
#  {'이름': '정진영',
#   '흥행지수': '1,945',
#   '랭킹': '47',
#   '원어명': '정진영',
#   '직업': '배우',
#   '생년월일': '1964-10-16',
#   '성별': '남',
#   '학교': '서울대학교 국어국문학'},
#  {'이름': '김영광',
#   '흥행지수': '1,878',
#   '랭킹': '48',
#   '직업': '배우',
#   '생년월일': '1987-01-11',
#   '성별': '남',
#   '홈페이지': '\nhttps://twitter.com/aksakfn12\nhttps://www.instagram.com/aksakfn12/\n'},
#  {'이름': '서강준',
#   '흥행지수': '1,811',
#   '랭킹': '49',
#   '다른 이름': '서프라이즈; 이승환',
#   '직업': '배우',
#   '생년월일': '1993-10-12',
#   '성별': '남',
#   '홈페이지': '\nhttps://www.instagram.com/seokj1012/\n'},
#  {'이름': '고성희',
#   '흥행지수': '1,677',
#   '랭킹': '50',
#   '직업': '배우',
#   '생년월일': '1990-06-21',
#   '성별': '여',
#   '홈페이지': '\nhttps://www.facebook.com/saram.gosunghee\nhttps://instagram.com/krnangel621\n'},
#  {'이름': '이진욱',
#   '흥행지수': '1,610',
#   '랭킹': '51',
#   '원어명': '이진욱',
#   '직업': '배우',
#   '생년월일': '1981-09-16',
#   '성별': '남',
#   '신장/체중': '185cm, 71kg',
#   '학교': '청주대학교 환경공학 (중퇴)',
#   '소속사': 'HB엔터테인먼트'},
#  {'이름': '조준영',
#   '흥행지수': '1,542',
#   '랭킹': '52',
#   '직업': '배우',
#   '생년월일': '2002-12-26',
#   '성별': '남'},
#  {'이름': '원지안',
#   '흥행지수': '1,475',
#   '랭킹': '53',
#   '직업': '배우',
#   '생년월일': '1999-08-17',
#   '성별': '여'},
#  {'이름': '이규형',
#   '흥행지수': '1,408',
#   '랭킹': '54',
#   '직업': '배우',
#   '생년월일': '1983-11-29',
#   '성별': '남',
#   '홈페이지': '\nhttps://twitter.com/kh_actor\nhttps://www.instagram.com/kh_actor/\n',
#   '학교': '동국대학교 연극과 학사'},
#  {'이름': '임성재',
#   '흥행지수': '1,350',
#   '랭킹': '55',
#   '직업': '배우',
#   '생년월일': '1987-01-18',
#   '성별': '남'},
#  {'이름': '박성일',
#   '흥행지수': '1,341',
#   '랭킹': '56',
#   '직업': '배우',
#   '생년월일': '1979-11-29',
#   '성별': '남'},
#  {'이름': '오인성',
#   '흥행지수': '1,302',
#   '랭킹': '57',
#   '직업': '성우',
#   '생년월일': '1965-11-04',
#   '성별': '남'},
#  {'이름': '이중옥', '흥행지수': '1,207', '랭킹': '58', '직업': '배우', '성별': '남'},
#  {'이름': '김승훈',
#   '흥행지수': '1,140',
#   '랭킹': '59',
#   '직업': '배우',
#   '생년월일': '1976-01-03',
#   '성별': '남'},
#  {'이름': '이숙희', '흥행지수': '1,126', '랭킹': '60', '성별': '여'},
#  {'이름': '배해선',
#   '흥행지수': '1,073',
#   '랭킹': '61',
#   '직업': '배우',
#   '생년월일': '1974-05-08',
#   '성별': '여'},
#  {'이름': '양정화',
#   '흥행지수': '1,014',
#   '랭킹': '62',
#   '직업': '성우',
#   '생년월일': '1970-11-27',
#   '성별': '여'},
#  {'이름': '남명렬',
#   '흥행지수': '1,006',
#   '랭킹': '63',
#   '직업': '배우',
#   '생년월일': '1959-05-14',
#   '성별': '남'}]
